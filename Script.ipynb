# %% [markdown]
# Installing condacolab untuk setting environtment

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:15
# 🔁 Restarting kernel...

# %% [markdown]
# Mount google drive untuk mengakses folder implementasi

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Check condacolab

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# Mengarahkan current directory ke directory program

# %%
# %cd drive/MyDrive/Deep3d/Deep3DFaceRecon_pytorch
# Out:
# /content/drive/MyDrive/Deep3d/Deep3DFaceRecon_pytorch

# %% [markdown]
# Create environtment pada anaconda dengan environtment.yml

# %%
# !conda env create -f environment.yml
# Out:
# - WARNING conda.models.version:get_matcher(546): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# WARNING conda.models.version:get_matcher(546): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.6.0.*, but conda is ignoring the .* and treating it as 1.6.0
# WARNING conda.models.version:get_matcher(546): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# WARNING conda.models.version:get_matcher(546): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# done
#
#
# ...

# %% [markdown]
# Pastikan environtment telah berhasil dibuat dan dapat digunakan dengan command dibawah

# %%
# !source activate deep3d_pytorch && conda env list
# Out:
# # conda environments:
# #
# base                     /usr/local
# deep3d_pytorch        *  /usr/local/envs/deep3d_pytorch

# %% [markdown]
# Install nvdiffrast folder. Nvdiffrast adalah library pytorch yang menyediakan high-performance primitive operations untuk rasterization-based differentiable rendering.

# %%
# %cd nvdiffrast
# Out:
# /content/drive/MyDrive/Deep3d/Deep3DFaceRecon_pytorch/nvdiffrast

# %%
# !source activate deep3d_pytorch && pip install .
# Out:
# Processing /content/drive/MyDrive/Deep3d/Deep3DFaceRecon_pytorch/nvdiffrast
# ...
#   Created wheel for nvdiffrast: filename=nvdiffrast-0.3.1-py3-none-any.whl size=137866 sha256=27667d6fc45cc6567dea3d508efdf32c7dd54ddb324c190e4821495846400ace
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3i164sy1/wheels/86/50/99/3ceecdbbc179d1c9a45153bef8f4a0337c8014c9d04f8ddeef
# Successfully built nvdiffrast
# ...

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/Deep3d/Deep3DFaceRecon_pytorch

# %% [markdown]
# Install libegl1-mesa-dev pada environtment yang telah dibuat tadi, library ini adalah paket library untuk pengembangan perangkat lunak dengan dukungan OpenGL dan OpenGL ES. Library ini menyediakan implementasi API EGL untuk mengelola konteks rendering

# %%
# !source activate deep3d_pytorch && apt-get install libegl1-mesa-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libegl-dev libgl-dev libgles-dev libgles1 libglvnd-core-dev libglvnd-dev libglx-dev libopengl-dev
# The following NEW packages will be installed:
#   libegl-dev libegl1-mesa-dev libgl-dev libgles-dev libgles1 libglvnd-core-dev libglvnd-dev
#   libglx-dev libopengl-dev
# 0 upgraded, 9 newly installed, 0 to remove and 24 not upgraded.
# Need to get 225 kB of archives.
# After this operation, 2,601 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# ...

# %% [markdown]
# Install libnvidia-gl untuk memastikan bahwa sistem memiliki library yang diperlukan untuk berinteraksi dengan driver grafis Nvidia. Ini bisa termasuk dukungan untuk OpenGL (Open Graphics Library) dan fitur-fitur grafis lainnya yang disediakan oleh Nvidia.

# %%
# !source activate deep3d_pytorch && apt install libnvidia-gl-470
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libnvidia-common-470 libnvidia-egl-wayland1
# The following NEW packages will be installed:
#   libnvidia-common-470 libnvidia-egl-wayland1 libnvidia-gl-470
# 0 upgraded, 3 newly installed, 0 to remove and 24 not upgraded.
# Need to get 152 MB of archives.
# After this operation, 353 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 libnvidia-common-470 all 470.223.02-0ubuntu0.22.04.1 [10.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnvidia-egl-wayland1 amd64 1:1.1.9-1.1 [26.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 libnvidia-gl-470 amd64 470.223.02-0ubuntu0.22.04.1 [152 MB]
# Fetched 152 MB in 10s (15.2 MB/s)
# Selecting previously unselected package libnvidia-common-470.
# ...

# %% [markdown]
# Jalankan test.py untuk mengeksekusi program, pada --name diisikan parameter untuk nama folder yang berada pada /checkpoints/ yang berisi file epoch, sedangkat --epoch adalah versi epoch yang digunakan, untuk --img_folder adalah folder dataset yang akan digunakan yang berisi image dan 5 landmarks detection untuk masing masing image.

# %%
# !source activate deep3d_pytorch && python test.py --name=model3 --epoch=20 --img_folder=./datasets/examples
# Out:
# /usr/local/envs/deep3d_pytorch/lib/python3.6/site-packages/kornia/augmentation/augmentation.py:1875: DeprecationWarning: GaussianBlur is no longer maintained and will be removed from the future versions. Please use RandomGaussianBlur instead.
#   category=DeprecationWarning,
# /usr/local/envs/deep3d_pytorch/lib/python3.6/site-packages/torch/utils/cpp_extension.py:4: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# ----------------- Options ---------------
#                 add_image: True
#                bfm_folder: BFM
#                 bfm_model: BFM_model_front.mat
#                  camera_d: 10.0
#                    center: 112.0
#           checkpoints_dir: ./checkpoints
#              dataset_mode: None
#                  ddp_port: 12355
#         display_per_batch: True
#                     epoch: 20                            	[default: latest]
#           eval_batch_nums: inf
# ...

# %% [markdown]
# Dibawah ini, kami mencoba untuk train ulang model yang telah dibuat

# %% [markdown]
# Prepare data yang akan digunakan

# %%
# !source activate deep3d_pytorch && python data_preparation.py --img_folder new_train
# Out:
# Datasets: ['new_train']
# WARNING:tensorflow:From /content/drive/MyDrive/Deep3d/Deep3DFaceRecon_pytorch/util/detect_lm68.py:40: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Deep3d/Deep3DFaceRecon_pytorch/util/detect_lm68.py:41: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Deep3d/Deep3DFaceRecon_pytorch/util/detect_lm68.py:48: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2023-12-09 06:57:33.219594: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-09 06:57:33.248407: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %% [markdown]
# validasi data yang telah di prepare

# %%
# !source activate deep3d_pytorch && python data_preparation.py --img_folder new_train --mode=val
# Out:
# Datasets: ['new_train']
# WARNING:tensorflow:From /content/drive/MyDrive/Deep3d/Deep3DFaceRecon_pytorch/util/detect_lm68.py:40: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Deep3d/Deep3DFaceRecon_pytorch/util/detect_lm68.py:41: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Deep3d/Deep3DFaceRecon_pytorch/util/detect_lm68.py:48: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2023-12-09 07:05:08.643151: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2023-12-09 07:05:08.662365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %% [markdown]
# lakukan train menggunakan data yang telah di validasi

# %%
# !source activate deep3d_pytorch && python train.py --name=training1 --gpu_ids=0
# Out:
# /usr/local/envs/deep3d_pytorch/lib/python3.6/site-packages/kornia/augmentation/augmentation.py:1875: DeprecationWarning: GaussianBlur is no longer maintained and will be removed from the future versions. Please use RandomGaussianBlur instead.
#   category=DeprecationWarning,
# ----------------- Options ---------------
#                 add_image: True
#                batch_size: 32
#            batch_size_val: 32
#                bfm_folder: BFM
#                 bfm_model: BFM_model_front.mat
#                  camera_d: 10.0
#                    center: 112.0
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 data_root: ./
#              dataset_mode: flist
#                  ddp_port: 12355
#              display_freq: 1000
#         display_per_batch: True
#                     epoch: latest
#               epoch_count: 1
#           eval_batch_nums: inf
#           evaluation_freq: 5000
# ...
